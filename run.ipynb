# %% [markdown]
# I obtained the file from the following website : https://mapper.obis.org/?taxonid=137092&areaid=31908&startdate=2010-01-01# it is in a tsv file so the first thing I had to do is convert it to a CSV file using Microsoft excel
